# %% [markdown]
# ## Imports

# %%
import pandas as pd

# %%
import pandas as pd

# Read only the first 5 rows of the file
df = pd.read_csv('Taxi_Trips_cleaned.csv', nrows=5)
display(df)
print(df.columns)
# Out:
#      Trip Start Timestamp      Trip End Timestamp  Trip Seconds  Trip Miles  \
# 0  06/29/2019 11:00:00 PM  06/29/2019 11:15:00 PM         307.0        0.40
# 1  03/31/2023 07:45:00 AM  03/31/2023 08:30:00 AM        2161.0        8.98
# 2  09/14/2020 03:15:00 PM  09/14/2020 03:30:00 PM        1368.0        2.87
# 3  09/26/2020 12:45:00 AM  09/26/2020 01:00:00 AM         780.0        4.70
# 4  08/21/2022 07:45:00 PM  08/21/2022 08:15:00 PM        2004.0       15.45
#
#     Fare  Tips  Tolls  Extras  Trip Total Payment Type              Company  \
# 0   4.75   0.0    0.0     1.0        5.75         Cash      Chicago Taxicab
# 1  30.00   0.0    0.0     1.0       31.00       Prcard            Flash Cab
# 2  13.75   0.0    0.0     0.0       13.75       Prcard            Flash Cab
# 3  15.00   0.0    0.0     0.0       15.00         Cash  Top Cab Affiliation
# 4  39.50   9.0    0.0     5.0       54.00       Mobile           Globe Taxi
#
# ...

# %%
df = pd.read_csv('Taxi_Trips_cleaned.csv')
display(df)
print(df.columns)
# Out:
#             Trip Start Timestamp      Trip End Timestamp  Trip Seconds  \
# 0         06/29/2019 11:00:00 PM  06/29/2019 11:15:00 PM         307.0
# 1         03/31/2023 07:45:00 AM  03/31/2023 08:30:00 AM        2161.0
# 2         09/14/2020 03:15:00 PM  09/14/2020 03:30:00 PM        1368.0
# 3         09/26/2020 12:45:00 AM  09/26/2020 01:00:00 AM         780.0
# 4         08/21/2022 07:45:00 PM  08/21/2022 08:15:00 PM        2004.0
# ...                          ...                     ...           ...
# 14705769  01/07/2015 06:30:00 PM  01/07/2015 06:30:00 PM           0.0
# 14705770  07/31/2015 08:00:00 PM  07/31/2015 08:00:00 PM           0.0
# 14705771  08/13/2015 10:15:00 AM  08/13/2015 10:15:00 AM           0.0
# 14705772  09/18/2019 07:45:00 PM  09/18/2019 07:45:00 PM           0.0
# 14705773  07/28/2015 09:45:00 PM  07/28/2015 10:15:00 PM        1140.0
#
#           Trip Miles   Fare  Tips  Tolls  Extras  Trip Total Payment Type  \
# ...
